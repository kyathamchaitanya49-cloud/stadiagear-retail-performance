# %%
import pandas as pd

sales = pd.read_csv("Sales_Fact.csv")
product = pd.read_csv("Product_Dimension.csv")

# %%
sales['Quantity'].describe()
# Out:
# count    20000.000000
# mean         2.995150
# std          1.420573
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: Quantity, dtype: float64

# %%
product['UnitPrice'].describe()
# Out:
# count    19999.000000
# mean        79.885408
# std         40.331699
# min         10.030000
# 25%         44.695000
# 50%         80.250000
# 75%        114.380000
# max        149.990000
# Name: UnitPrice, dtype: float64

# %%
sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales[sales.duplicated()]
# Out:
# Empty DataFrame
# Columns: [TransactionID, CustomerID, ProductID, Region, Quantity, Revenue]
# Index: []

# %%
sales_clean = sales.drop_duplicates()

# %%
sales_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales_clean.to_csv("stadiagear_clean.csv", index=False)

# %%
import os

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Customer Dimension.ipynb',
#  'Customer_Dimension.csv',
#  'customer_spending_tiers.csv',
#  'Data cleaning of sales data.ipynb',
#  'day3.ipynb',
#  'Inventory_Dimension.csv',
#  'Inventory_Dimension.ipynb',
#  'Product_Dimension.csv',
#  'Product_Dimension.ipynb',
#  'Region_Dimension.csv',
#  'Sales_Fact.csv',
#  'sales_fact.ipynb',
#  'Sales_Fact_Updated.csv',
#  'stadiagear_clean.csv',
#  'StadiaGear_Retail_Performance .ipynb',
#  'StadiaGear_Retail_Performance_20000_Rows1.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb']
